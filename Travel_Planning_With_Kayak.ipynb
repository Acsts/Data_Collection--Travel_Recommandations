# %% [markdown]
# # Project : Plan your trip with Kayak

# %%
import pandas as pd
pd.options.display.max_columns = 100

# %% [markdown]
# ## 'Extract' : Collect the data

# %%
cities = ["Mont Saint Michel",
"St Malo",
"Bayeux",
"Le Havre",
"Rouen",
"Paris",
"Amiens",
"Lille",
"Strasbourg",
"Chateau du Haut Koenigsbourg",
"Colmar",
"Eguisheim",
"Besancon",
"Dijon",
"Annecy",
"Grenoble",
"Lyon",
"Gorges du Verdon",
"Bormes les Mimosas",
"Cassis",
"Marseille",
"Aix en Provence",
"Avignon",
"Uzes",
"Nimes",
"Aigues Mortes",
"Saintes Maries de la mer",
"Collioure",
"Carcassonne",
"Ariege",
"Toulouse",
"Montauban",
"Biarritz",
"Bayonne",
"La Rochelle"]

# %% [markdown]
# ### Get weather data via an API :

# %%
import requests
import time

city = cities[0]
r = requests.get('https://nominatim.openstreetmap.org/search?format=json&city='+city)
city_json = r.json()[0] #We consider the first search result as the most relevant one

city_json
# Out:
# {'place_id': 156094736,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 211285890,
#  'boundingbox': ['48.6349172', '48.637031', '-1.5133292', '-1.5094796'],
#  'lat': '48.6359541',
#  'lon': '-1.511459954959514',
#  'display_name': 'Mont Saint-Michel, Le Mont-Saint-Michel, Avranches, Manche, Normandie, France métropolitaine, 50170, France',
#  'class': 'place',
#  'type': 'islet',
#  'importance': 0.755436556781574}

# %%
name = city_json['display_name']
lat = city_json['lat']
lon = city_json['lon']
print(f"{name} : \n -- latitude : {lat} \n -- longitude : {lon}")
# Out:
# Mont Saint-Michel, Le Mont-Saint-Michel, Avranches, Manche, Normandie, France métropolitaine, 50170, France :
#  -- latitude : 48.6359541
#  -- longitude : -1.511459954959514

# %% [markdown]
# #### Generalization to the 35 cities list - Collecting the geoloc data and storing it into a list of json files

# %%
import os
import logging

geolocs_info = []

for city in cities:
    r = requests.get('https://nominatim.openstreetmap.org/search?format=json&city='+city)
    city_json = r.json()[0]
    print(city)
    #logging.info(f"Storing data for {city_json['display_name']}...", end ='')
    geolocs_info.append(city_json)
    #logging.info("done.")
    time.sleep(1) #wait for 1sec between requests to respect Nominatim's Usage Policy
# Out:
# Mont Saint Michel
# St Malo
# Bayeux
# Le Havre
# Rouen
# Paris
# Amiens
# Lille
# Strasbourg
# Chateau du Haut Koenigsbourg
# Colmar
# Eguisheim
# Besancon
# Dijon
# Annecy
# Grenoble
# Lyon
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [5], in <module>
#       6 for city in cities:
#       7     r = requests.get('https://nominatim.openstreetmap.org/search?format=json&city='+city)
# ----> 8     city_json = r.json()[0]
#       9     print(city)
#      10     #logging.info(f"Storing data for {city_json['display_name']}...", end ='')
#
# IndexError: list index out of range

# %% [markdown]
# We have a problem with "Gorges du Verdon", probably because it's not litterally a city and therefore the API does not find anything in response to the request type 'city='.
# We will hence do a type 'q=' request which perform a more generalist search query:

# %%
import os
import logging

geolocs_info = []

for city in cities:
    r = requests.get('https://nominatim.openstreetmap.org/search?format=json&q=France,'+city) #We add 'France' in the query to be more specific
    city_json = r.json()[0]
    city_json['city'] = city
    print(city, "...done")
    #logging.info(f"Storing data for {city_json['display_name']}...", end ='')
    geolocs_info.append(city_json)
    #logging.info("done.")
    time.sleep(1) #wait for 1sec between requests to respect Nominatim's Usage Policy
# Out:
# Mont Saint Michel ...done
# St Malo ...done
# Bayeux ...done
# Le Havre ...done
# Rouen ...done
# Paris ...done
# Amiens ...done
# Lille ...done
# Strasbourg ...done
# Chateau du Haut Koenigsbourg ...done
# Colmar ...done
# Eguisheim ...done
# Besancon ...done
# Dijon ...done
# Annecy ...done
# Grenoble ...done
# Lyon ...done
# Gorges du Verdon ...done
# Bormes les Mimosas ...done
# Cassis ...done
# Marseille ...done
# Aix en Provence ...done
# Avignon ...done
# Uzes ...done
# Nimes ...done
# Aigues Mortes ...done
# Saintes Maries de la mer ...done
# Collioure ...done
# Carcassonne ...done
# Ariege ...done
# Toulouse ...done
# Montauban ...done
# Biarritz ...done
# Bayonne ...done
# La Rochelle ...done

# %%
geolocs_info
# Out:
# [{'place_id': 156094680,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 211285890,
#   'boundingbox': ['48.6349172', '48.637031', '-1.5133292', '-1.5094796'],
#   'lat': '48.6359541',
#   'lon': '-1.511459954959514',
#   'display_name': 'Mont Saint-Michel, Plateforme du Saut-\xadGaultier, Le Mont-Saint-Michel, Avranches, Manche, Normandie, France métropolitaine, 50170, France',
#   'class': 'tourism',
#   'type': 'attraction',
#   'importance': 0.8654365567815739,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_point_of_interest.p.20.png',
#   'city': 'Mont Saint Michel'},
#  {'place_id': 297756747,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 905534,
#   'boundingbox': ['48.5979853', '48.6949736', '-2.0765246', '-1.9367259'],
#   'lat': '48.649518',
#   'lon': '-2.0260409',
#   'display_name': 'Saint-Malo, Ille-et-Vilaine, Bretagne, France métropolitaine, 35400, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7864672172428953,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'St Malo'},
#  {'place_id': 297981358,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 145776,
#   'boundingbox': ['49.2608124', '49.2934736', '-0.7275671', '-0.6757378'],
#   'lat': '49.2764624',
#   'lon': '-0.7024738',
#   'display_name': 'Bayeux, Calvados, Normandie, France métropolitaine, 14400, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7927003853621928,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Bayeux'},
#  {'place_id': 298137491,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 104492,
#   'boundingbox': ['49.4516697', '49.5401463', '0.0667992', '0.1955556'],
#   'lat': '49.4938975',
#   'lon': '0.1079732',
#   'display_name': 'Le Havre, Seine-Maritime, Normandie, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9323325741883645,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Le Havre'},
#  {'place_id': 297518815,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 75628,
#   'boundingbox': ['49.4172001', '49.4652601', '1.0300648', '1.1521157'],
#   'lat': '49.4404591',
#   'lon': '1.0939658',
#   'display_name': 'Rouen, Seine-Maritime, Normandie, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8600726280583955,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Rouen'},
#  {'place_id': 297417241,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 7444,
#   'boundingbox': ['48.8155755', '48.902156', '2.224122', '2.4697602'],
#   'lat': '48.8588897',
#   'lon': '2.3200410217200766',
#   'display_name': 'Paris, Île-de-France, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 1.0517101715588673,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Paris'},
#  {'place_id': 297534793,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 114347,
#   'boundingbox': ['49.846837', '49.9505487', '2.2235574', '2.3457767'],
#   'lat': '49.8941708',
#   'lon': '2.2956951',
#   'display_name': 'Amiens, Somme, Hauts-de-France, France métropolitaine, 80090, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.844948962224904,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Amiens'},
#  {'place_id': 297472400,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 58404,
#   'boundingbox': ['50.6008264', '50.6612596', '2.9679677', '3.125725'],
#   'lat': '50.6365654',
#   'lon': '3.0635282',
#   'display_name': 'Lille, Nord, Hauts-de-France, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8732037863087654,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Lille'},
#  {'place_id': 297508568,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 71033,
#   'boundingbox': ['48.491861', '48.6461896', '7.6881371', '7.8360646'],
#   'lat': '48.584614',
#   'lon': '7.7507127',
#   'display_name': 'Strasbourg, Bas-Rhin, Grand Est, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8948054279118731,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Strasbourg'},
#  {'place_id': 120791766,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 61044809,
#   'boundingbox': ['48.249302', '48.2496794', '7.3436964', '7.3449443'],
#   'lat': '48.249489800000006',
#   'lon': '7.34429620253195',
#   'display_name': 'Château du Haut-Kœnigsbourg, Chemin fermé suite  à travaux, Château du Haut-Kœnigsbourg, Orschwiller, Sélestat-Erstein, Bas-Rhin, Grand Est, France métropolitaine, 67600, France',
#   'class': 'historic',
#   'type': 'castle',
#   'importance': 0.6639550660685245,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/tourist_castle.p.20.png',
#   'city': 'Chateau du Haut Koenigsbourg'},
#  {'place_id': 297504747,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 61423,
#   'boundingbox': ['48.0407053', '48.182062', '7.3154803', '7.469167'],
#   'lat': '48.0777517',
#   'lon': '7.3579641',
#   'display_name': 'Colmar, Colmar-Ribeauvillé, Haut-Rhin, Grand Est, France métropolitaine, 68000, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6909087464752242,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Colmar'},
#  {'place_id': 297869324,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 79442,
#   'boundingbox': ['48.0240327', '48.0515072', '7.2412792', '7.351854'],
#   'lat': '48.0447968',
#   'lon': '7.3079618',
#   'display_name': 'Eguisheim, Colmar-Ribeauvillé, Haut-Rhin, Grand Est, France métropolitaine, 68420, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7449720206561967,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Eguisheim'},
#  {'place_id': 297668227,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 103599,
#   'boundingbox': ['47.2006872', '47.3200746', '5.9409668', '6.0835059'],
#   'lat': '47.2380222',
#   'lon': '6.0243622',
#   'display_name': 'Besançon, Doubs, Bourgogne-Franche-Comté, France métropolitaine, 25000, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7283511874833898,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Besancon'},
#  {'place_id': 297478568,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 74090,
#   'boundingbox': ['47.2862467', '47.377486', '4.9624434', '5.1020598'],
#   'lat': '47.3215806',
#   'lon': '5.0414701',
#   'display_name': "Dijon, Côte-d'Or, Bourgogne-Franche-Comté, France métropolitaine, 21000, France",
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8536193867801005,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Dijon'},
#  {'place_id': 298516920,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 6791758,
#   'boundingbox': ['45.8280024', '45.9766928', '6.0484121', '6.2043932'],
#   'lat': '45.8992348',
#   'lon': '6.1288847',
#   'display_name': 'Annecy, Haute-Savoie, Auvergne-Rhône-Alpes, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7990769115704566,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Annecy'},
#  {'place_id': 297639071,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 80348,
#   'boundingbox': ['45.1541442', '45.2140762', '5.6776059', '5.7531176'],
#   'lat': '45.1875602',
#   'lon': '5.7357819',
#   'display_name': 'Grenoble, Isère, Auvergne-Rhône-Alpes, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8618085495723451,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Grenoble'},
#  {'place_id': 297681191,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 120965,
#   'boundingbox': ['45.7073666', '45.8082628', '4.7718134', '4.8983774'],
#   'lat': '45.7578137',
#   'lon': '4.8320114',
#   'display_name': 'Lyon, Métropole de Lyon, Circonscription départementale du Rhône, Auvergne-Rhône-Alpes, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9113775965432667,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Lyon'},
#  {'place_id': 76036307,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 7193513219,
#   'boundingbox': ['43.7496062', '43.7497062', '6.3285116', '6.3286116'],
#   'lat': '43.7496562',
#   'lon': '6.3285616',
#   'display_name': "Gorges du Verdon, Route des Crêtes, Les Ferrailles, La Palud-sur-Verdon, Castellane, Alpes-de-Haute-Provence, Provence-Alpes-Côte d'Azur, France métropolitaine, 04120, France",
#   'class': 'tourism',
#   'type': 'attraction',
#   'importance': 0.7881495857429428,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_point_of_interest.p.20.png',
#   'city': 'Gorges du Verdon'},
#  {'place_id': 297749145,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 1118915,
#   'boundingbox': ['43.0864271', '43.2278201', '6.2716142', '6.4514893'],
#   'lat': '43.1506968',
#   'lon': '6.3419285',
#   'display_name': "Bormes-les-Mimosas, Toulon, Var, Provence-Alpes-Côte d'Azur, France métropolitaine, 83230, France",
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8873164194582208,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Bormes les Mimosas'},
#  {'place_id': 298072685,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 76425,
#   'boundingbox': ['43.1884732', '43.2487231', '5.5063193', '5.5945199'],
#   'lat': '43.2140359',
#   'lon': '5.5396318',
#   'display_name': "Cassis, Marseille, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13260, France",
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6967802490530643,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Cassis'},
#  {'place_id': 297763730,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 76469,
#   'boundingbox': ['43.1696228', '43.3910329', '5.2286312', '5.5324758'],
#   'lat': '43.2961743',
#   'lon': '5.3699525',
#   'display_name': "Marseille, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13000, France",
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9013768937556641,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Marseille'},
#  {'place_id': 297906924,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 70279,
#   'boundingbox': ['43.4461058', '43.6259224', '5.2694745', '5.5063013'],
#   'lat': '43.5298424',
#   'lon': '5.4474738',
#   'display_name': "Aix-en-Provence, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, France",
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 1.0010847663837579,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Aix en Provence'},
#  {'place_id': 297768703,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 102478,
#   'boundingbox': ['43.8866543', '43.9967419', '4.7396309', '4.9271468'],
#   'lat': '43.9492493',
#   'lon': '4.8059012',
#   'display_name': "Avignon, Vaucluse, Provence-Alpes-Côte d'Azur, France métropolitaine, France",
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8420935210501683,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Avignon'},
#  {'place_id': 297655586,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 380050,
#   'boundingbox': ['43.9811093', '44.0765914', '4.3852299', '4.4467859'],
#   'lat': '44.0121279',
#   'lon': '4.4196718',
#   'display_name': 'Uzès, Nîmes, Gard, Occitanie, France métropolitaine, 30700, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6475332788749554,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Uzes'},
#  {'place_id': 297997049,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 378685,
#   'boundingbox': ['43.7412659', '43.9230177', '4.2356708', '4.4496605'],
#   'lat': '43.8374249',
#   'lon': '4.3600687',
#   'display_name': 'Nîmes, Gard, Occitanie, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7130547856893241,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Nimes'},
#  {'place_id': 298018344,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 272287,
#   'boundingbox': ['43.4958113', '43.5920372', '4.0760703', '4.2442867'],
#   'lat': '43.5658225',
#   'lon': '4.1912837',
#   'display_name': 'Aigues-Mortes, Nîmes, Gard, Occitanie, France métropolitaine, 30220, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8423802893018254,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Aigues Mortes'},
#  {'place_id': 298011281,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 414459,
#   'boundingbox': ['43.4062445', '43.5858463', '4.2301364', '4.6444785'],
#   'lat': '43.4522771',
#   'lon': '4.4287172',
#   'display_name': "Saintes-Maries-de-la-Mer, Arles, Bouches-du-Rhône, Provence-Alpes-Côte d'Azur, France métropolitaine, 13460, France",
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 1.0825165122764473,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Saintes Maries de la mer'},
#  {'place_id': 298221742,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 18409,
#   'boundingbox': ['42.4832453', '42.5341084', '3.0495074', '3.0994238'],
#   'lat': '42.52505',
#   'lon': '3.0831554',
#   'display_name': 'Collioure, Céret, Pyrénées-Orientales, Occitanie, France métropolitaine, 66190, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7284088842062248,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Collioure'},
#  {'place_id': 297466626,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 37774,
#   'boundingbox': ['43.1713069', '43.2443707', '2.2615684', '2.4362676'],
#   'lat': '43.2130358',
#   'lon': '2.3491069',
#   'display_name': 'Carcassonne, Aude, Occitanie, France métropolitaine, 11000, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8091672924570599,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Carcassonne'},
#  {'place_id': 297389050,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 7439,
#   'boundingbox': ['42.5732416', '43.3162514', '0.8267506', '2.1758135'],
#   'lat': '42.9455368',
#   'lon': '1.4065544156065486',
#   'display_name': 'Ariège, Occitanie, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7109114788084189,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Ariege'},
#  {'place_id': 298222566,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 35738,
#   'boundingbox': ['43.532654', '43.668708', '1.3503956', '1.5153795'],
#   'lat': '43.6044622',
#   'lon': '1.4442469',
#   'display_name': 'Toulouse, Haute-Garonne, Occitanie, France métropolitaine, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8882142268493705,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Toulouse'},
#  {'place_id': 297932490,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 137735,
#   'boundingbox': ['43.9512579', '44.0922122', '1.2865419', '1.4427914'],
#   'lat': '44.0175835',
#   'lon': '1.3549991',
#   'display_name': 'Montauban, Tarn-et-Garonne, Occitanie, France métropolitaine, 82000, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.7742482145338698,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Montauban'},
#  {'place_id': 298516909,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 4615703,
#   'boundingbox': ['43.4475698', '43.4945381', '-1.5773906', '-1.5343915'],
#   'lat': '43.471143749999996',
#   'lon': '-1.552726590666314',
#   'display_name': 'Biarritz, Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquitaine, France métropolitaine, 64200, France',
#   'class': 'boundary',
#   'type': 'political',
#   'importance': 0.7996122503321825,
#   'city': 'Biarritz'},
#  {'place_id': 298271847,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 166713,
#   'boundingbox': ['43.4498733', '43.5188846', '-1.5048438', '-1.417261'],
#   'lat': '43.4945144',
#   'lon': '-1.4736657',
#   'display_name': 'Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquitaine, France métropolitaine, 64100, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.8227800210035323,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'Bayonne'},
#  {'place_id': 297653650,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 117858,
#   'boundingbox': ['46.1331804', '46.1908971', '-1.2419231', '-1.111097'],
#   'lat': '46.1591126',
#   'lon': '-1.1520434',
#   'display_name': 'La Rochelle, Charente-Maritime, Nouvelle-Aquitaine, France métropolitaine, 17000, France',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.9114837096874572,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png',
#   'city': 'La Rochelle'}]

# %% [markdown]
# Formatting the data into a Pandas dataframe :

# %%
geolocs_df = pd.DataFrame(geolocs_info)
display(geolocs_df)
# Out:
#      place_id                                            licence  osm_type  \
# 0   156094680  Data © OpenStreetMap contributors, ODbL 1.0. h...       way
# 1   297756747  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 2   297981358  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 3   298137491  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 4   297518815  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 5   297417241  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 6   297534793  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 7   297472400  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 8   297508568  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 9   120791766  Data © OpenStreetMap contributors, ODbL 1.0. h...       way
# 10  297504747  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 11  297869324  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 12  297668227  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 13  297478568  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 14  298516920  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 15  297639071  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 16  297681191  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 17   76036307  Data © OpenStreetMap contributors, ODbL 1.0. h...      node
# 18  297749145  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 19  298072685  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 20  297763730  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 21  297906924  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 22  297768703  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 23  297655586  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 24  297997049  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 25  298018344  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 26  298011281  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 27  298221742  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 28  297466626  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 29  297389050  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 30  298222566  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 31  297932490  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 32  298516909  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 33  298271847  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
# 34  297653650  Data © OpenStreetMap contributors, ODbL 1.0. h...  relation
#
#         osm_id                                       boundingbox  \
# 0    211285890   [48.6349172, 48.637031, -1.5133292, -1.5094796]
# 1       905534  [48.5979853, 48.6949736, -2.0765246, -1.9367259]
# 2       145776  [49.2608124, 49.2934736, -0.7275671, -0.6757378]
# 3       104492    [49.4516697, 49.5401463, 0.0667992, 0.1955556]
# 4        75628    [49.4172001, 49.4652601, 1.0300648, 1.1521157]
# 5         7444      [48.8155755, 48.902156, 2.224122, 2.4697602]
# 6       114347     [49.846837, 49.9505487, 2.2235574, 2.3457767]
# 7        58404     [50.6008264, 50.6612596, 2.9679677, 3.125725]
# 8        71033     [48.491861, 48.6461896, 7.6881371, 7.8360646]
# 9     61044809     [48.249302, 48.2496794, 7.3436964, 7.3449443]
# 10       61423      [48.0407053, 48.182062, 7.3154803, 7.469167]
# 11       79442     [48.0240327, 48.0515072, 7.2412792, 7.351854]
# 12      103599    [47.2006872, 47.3200746, 5.9409668, 6.0835059]
# 13       74090     [47.2862467, 47.377486, 4.9624434, 5.1020598]
# 14     6791758    [45.8280024, 45.9766928, 6.0484121, 6.2043932]
# 15       80348    [45.1541442, 45.2140762, 5.6776059, 5.7531176]
# 16      120965    [45.7073666, 45.8082628, 4.7718134, 4.8983774]
# 17  7193513219    [43.7496062, 43.7497062, 6.3285116, 6.3286116]
# 18     1118915    [43.0864271, 43.2278201, 6.2716142, 6.4514893]
# 19       76425    [43.1884732, 43.2487231, 5.5063193, 5.5945199]
# 20       76469    [43.1696228, 43.3910329, 5.2286312, 5.5324758]
# 21       70279    [43.4461058, 43.6259224, 5.2694745, 5.5063013]
# 22      102478    [43.8866543, 43.9967419, 4.7396309, 4.9271468]
# 23      380050    [43.9811093, 44.0765914, 4.3852299, 4.4467859]
# 24      378685    [43.7412659, 43.9230177, 4.2356708, 4.4496605]
# 25      272287    [43.4958113, 43.5920372, 4.0760703, 4.2442867]
# 26      414459    [43.4062445, 43.5858463, 4.2301364, 4.6444785]
# 27       18409    [42.4832453, 42.5341084, 3.0495074, 3.0994238]
# 28       37774    [43.1713069, 43.2443707, 2.2615684, 2.4362676]
# 29        7439    [42.5732416, 43.3162514, 0.8267506, 2.1758135]
# 30       35738      [43.532654, 43.668708, 1.3503956, 1.5153795]
# 31      137735    [43.9512579, 44.0922122, 1.2865419, 1.4427914]
# 32     4615703  [43.4475698, 43.4945381, -1.5773906, -1.5343915]
# 33      166713   [43.4498733, 43.5188846, -1.5048438, -1.417261]
# 34      117858   [46.1331804, 46.1908971, -1.2419231, -1.111097]
#
#                    lat                 lon  \
# 0           48.6359541  -1.511459954959514
# 1            48.649518          -2.0260409
# 2           49.2764624          -0.7024738
# 3           49.4938975           0.1079732
# 4           49.4404591           1.0939658
# 5           48.8588897  2.3200410217200766
# 6           49.8941708           2.2956951
# 7           50.6365654           3.0635282
# 8            48.584614           7.7507127
# 9   48.249489800000006    7.34429620253195
# 10          48.0777517           7.3579641
# 11          48.0447968           7.3079618
# 12          47.2380222           6.0243622
# 13          47.3215806           5.0414701
# 14          45.8992348           6.1288847
# 15          45.1875602           5.7357819
# 16          45.7578137           4.8320114
# 17          43.7496562           6.3285616
# 18          43.1506968           6.3419285
# 19          43.2140359           5.5396318
# 20          43.2961743           5.3699525
# 21          43.5298424           5.4474738
# 22          43.9492493           4.8059012
# 23          44.0121279           4.4196718
# 24          43.8374249           4.3600687
# 25          43.5658225           4.1912837
# 26          43.4522771           4.4287172
# 27            42.52505           3.0831554
# 28          43.2130358           2.3491069
# 29          42.9455368  1.4065544156065486
# 30          43.6044622           1.4442469
# 31          44.0175835           1.3549991
# 32  43.471143749999996  -1.552726590666314
# 33          43.4945144          -1.4736657
# 34          46.1591126          -1.1520434
#
#                                          display_name     class  \
# 0   Mont Saint-Michel, Plateforme du Saut-­Gaultie...   tourism
# 1   Saint-Malo, Ille-et-Vilaine, Bretagne, France ...  boundary
# 2   Bayeux, Calvados, Normandie, France métropolit...  boundary
# 3   Le Havre, Seine-Maritime, Normandie, France mé...  boundary
# 4   Rouen, Seine-Maritime, Normandie, France métro...  boundary
# 5   Paris, Île-de-France, France métropolitaine, F...  boundary
# 6   Amiens, Somme, Hauts-de-France, France métropo...  boundary
# 7   Lille, Nord, Hauts-de-France, France métropoli...  boundary
# 8   Strasbourg, Bas-Rhin, Grand Est, France métrop...  boundary
# 9   Château du Haut-Kœnigsbourg, Chemin fermé suit...  historic
# 10  Colmar, Colmar-Ribeauvillé, Haut-Rhin, Grand E...  boundary
# 11  Eguisheim, Colmar-Ribeauvillé, Haut-Rhin, Gran...  boundary
# 12  Besançon, Doubs, Bourgogne-Franche-Comté, Fran...  boundary
# 13  Dijon, Côte-d'Or, Bourgogne-Franche-Comté, Fra...  boundary
# 14  Annecy, Haute-Savoie, Auvergne-Rhône-Alpes, Fr...  boundary
# 15  Grenoble, Isère, Auvergne-Rhône-Alpes, France ...  boundary
# 16  Lyon, Métropole de Lyon, Circonscription dépar...  boundary
# 17  Gorges du Verdon, Route des Crêtes, Les Ferrai...   tourism
# 18  Bormes-les-Mimosas, Toulon, Var, Provence-Alpe...  boundary
# 19  Cassis, Marseille, Bouches-du-Rhône, Provence-...  boundary
# 20  Marseille, Bouches-du-Rhône, Provence-Alpes-Cô...  boundary
# 21  Aix-en-Provence, Bouches-du-Rhône, Provence-Al...  boundary
# 22  Avignon, Vaucluse, Provence-Alpes-Côte d'Azur,...  boundary
# 23  Uzès, Nîmes, Gard, Occitanie, France métropoli...  boundary
# 24  Nîmes, Gard, Occitanie, France métropolitaine,...  boundary
# 25  Aigues-Mortes, Nîmes, Gard, Occitanie, France ...  boundary
# 26  Saintes-Maries-de-la-Mer, Arles, Bouches-du-Rh...  boundary
# 27  Collioure, Céret, Pyrénées-Orientales, Occitan...  boundary
# 28  Carcassonne, Aude, Occitanie, France métropoli...  boundary
# 29   Ariège, Occitanie, France métropolitaine, France  boundary
# 30  Toulouse, Haute-Garonne, Occitanie, France mét...  boundary
# 31  Montauban, Tarn-et-Garonne, Occitanie, France ...  boundary
# 32  Biarritz, Bayonne, Pyrénées-Atlantiques, Nouve...  boundary
# 33  Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquita...  boundary
# 34  La Rochelle, Charente-Maritime, Nouvelle-Aquit...  boundary
#
#               type  importance  \
# 0       attraction    0.865437
# 1   administrative    0.786467
# 2   administrative    0.792700
# 3   administrative    0.932333
# 4   administrative    0.860073
# 5   administrative    1.051710
# 6   administrative    0.844949
# 7   administrative    0.873204
# 8   administrative    0.894805
# 9           castle    0.663955
# 10  administrative    0.690909
# 11  administrative    0.744972
# 12  administrative    0.728351
# 13  administrative    0.853619
# 14  administrative    0.799077
# 15  administrative    0.861809
# 16  administrative    0.911378
# 17      attraction    0.788150
# 18  administrative    0.887316
# 19  administrative    0.696780
# 20  administrative    0.901377
# 21  administrative    1.001085
# 22  administrative    0.842094
# 23  administrative    0.647533
# 24  administrative    0.713055
# 25  administrative    0.842380
# 26  administrative    1.082517
# 27  administrative    0.728409
# 28  administrative    0.809167
# 29  administrative    0.710911
# 30  administrative    0.888214
# 31  administrative    0.774248
# 32       political    0.799612
# 33  administrative    0.822780
# 34  administrative    0.911484
#
#                                                  icon  \
# 0   https://nominatim.openstreetmap.org/ui/mapicon...
# 1   https://nominatim.openstreetmap.org/ui/mapicon...
# 2   https://nominatim.openstreetmap.org/ui/mapicon...
# 3   https://nominatim.openstreetmap.org/ui/mapicon...
# 4   https://nominatim.openstreetmap.org/ui/mapicon...
# 5   https://nominatim.openstreetmap.org/ui/mapicon...
# 6   https://nominatim.openstreetmap.org/ui/mapicon...
# 7   https://nominatim.openstreetmap.org/ui/mapicon...
# 8   https://nominatim.openstreetmap.org/ui/mapicon...
# 9   https://nominatim.openstreetmap.org/ui/mapicon...
# 10  https://nominatim.openstreetmap.org/ui/mapicon...
# 11  https://nominatim.openstreetmap.org/ui/mapicon...
# 12  https://nominatim.openstreetmap.org/ui/mapicon...
# 13  https://nominatim.openstreetmap.org/ui/mapicon...
# 14  https://nominatim.openstreetmap.org/ui/mapicon...
# 15  https://nominatim.openstreetmap.org/ui/mapicon...
# 16  https://nominatim.openstreetmap.org/ui/mapicon...
# 17  https://nominatim.openstreetmap.org/ui/mapicon...
# 18  https://nominatim.openstreetmap.org/ui/mapicon...
# 19  https://nominatim.openstreetmap.org/ui/mapicon...
# 20  https://nominatim.openstreetmap.org/ui/mapicon...
# 21  https://nominatim.openstreetmap.org/ui/mapicon...
# 22  https://nominatim.openstreetmap.org/ui/mapicon...
# 23  https://nominatim.openstreetmap.org/ui/mapicon...
# 24  https://nominatim.openstreetmap.org/ui/mapicon...
# 25  https://nominatim.openstreetmap.org/ui/mapicon...
# 26  https://nominatim.openstreetmap.org/ui/mapicon...
# 27  https://nominatim.openstreetmap.org/ui/mapicon...
# 28  https://nominatim.openstreetmap.org/ui/mapicon...
# 29  https://nominatim.openstreetmap.org/ui/mapicon...
# 30  https://nominatim.openstreetmap.org/ui/mapicon...
# 31  https://nominatim.openstreetmap.org/ui/mapicon...
# 32                                                NaN
# 33  https://nominatim.openstreetmap.org/ui/mapicon...
# 34  https://nominatim.openstreetmap.org/ui/mapicon...
#
#                             city
# 0              Mont Saint Michel
# 1                        St Malo
# 2                         Bayeux
# 3                       Le Havre
# 4                          Rouen
# 5                          Paris
# 6                         Amiens
# 7                          Lille
# 8                     Strasbourg
# 9   Chateau du Haut Koenigsbourg
# 10                        Colmar
# 11                     Eguisheim
# 12                      Besancon
# 13                         Dijon
# 14                        Annecy
# 15                      Grenoble
# 16                          Lyon
# 17              Gorges du Verdon
# 18            Bormes les Mimosas
# 19                        Cassis
# 20                     Marseille
# 21               Aix en Provence
# 22                       Avignon
# 23                          Uzes
# 24                         Nimes
# 25                 Aigues Mortes
# 26      Saintes Maries de la mer
# 27                     Collioure
# 28                   Carcassonne
# 29                        Ariege
# 30                      Toulouse
# 31                     Montauban
# 32                      Biarritz
# 33                       Bayonne
# 34                   La Rochelle

# %%
geolocs_df = geolocs_df.drop(columns = ['licence','osm_type','osm_id'])

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.9/site-packages (0.20.0)

# %%
from dotenv import load_dotenv
import os
load_dotenv()
api_key = os.getenv('api_key') #API_key obtained after free subscription
units = 'metric'
lat, lon = (geolocs_df[_][0] for _ in ['lat','lon'])
r = requests.get(f'https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&appid={api_key}&units={units}')
weather_json = r.json() #We consider the first search result as the most relevant one
weather_json['city']=cities[0]
weather_json
# Out:
# {'lat': 48.636,
#  'lon': -1.5115,
#  'timezone': 'Europe/Paris',
#  'timezone_offset': 7200,
#  'current': {'dt': 1659476127,
#   'sunrise': 1659415270,
#   'sunset': 1659469402,
#   'temp': 18.39,
#   'feels_like': 18.77,
#   'pressure': 1017,
#   'humidity': 95,
#   'dew_point': 17.58,
#   'uvi': 0,
#   'clouds': 48,
#   'visibility': 10000,
#   'wind_speed': 3.23,
#   'wind_deg': 349,
#   'wind_gust': 6.05,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}]},
#  'minutely': [{'dt': 1659476160, 'precipitation': 0},
#   {'dt': 1659476220, 'precipitation': 0},
#   {'dt': 1659476280, 'precipitation': 0},
#   {'dt': 1659476340, 'precipitation': 0},
#   {'dt': 1659476400, 'precipitation': 0},
#   {'dt': 1659476460, 'precipitation': 0},
#   {'dt': 1659476520, 'precipitation': 0},
#   {'dt': 1659476580, 'precipitation': 0},
#   {'dt': 1659476640, 'precipitation': 0},
#   {'dt': 1659476700, 'precipitation': 0},
#   {'dt': 1659476760, 'precipitation': 0},
#   {'dt': 1659476820, 'precipitation': 0},
#   {'dt': 1659476880, 'precipitation': 0},
#   {'dt': 1659476940, 'precipitation': 0},
#   {'dt': 1659477000, 'precipitation': 0},
#   {'dt': 1659477060, 'precipitation': 0},
#   {'dt': 1659477120, 'precipitation': 0},
#   {'dt': 1659477180, 'precipitation': 0},
#   {'dt': 1659477240, 'precipitation': 0},
#   {'dt': 1659477300, 'precipitation': 0},
#   {'dt': 1659477360, 'precipitation': 0},
#   {'dt': 1659477420, 'precipitation': 0},
#   {'dt': 1659477480, 'precipitation': 0},
#   {'dt': 1659477540, 'precipitation': 0},
#   {'dt': 1659477600, 'precipitation': 0},
#   {'dt': 1659477660, 'precipitation': 0},
#   {'dt': 1659477720, 'precipitation': 0},
#   {'dt': 1659477780, 'precipitation': 0},
#   {'dt': 1659477840, 'precipitation': 0},
#   {'dt': 1659477900, 'precipitation': 0},
#   {'dt': 1659477960, 'precipitation': 0},
#   {'dt': 1659478020, 'precipitation': 0},
#   {'dt': 1659478080, 'precipitation': 0},
#   {'dt': 1659478140, 'precipitation': 0},
#   {'dt': 1659478200, 'precipitation': 0},
#   {'dt': 1659478260, 'precipitation': 0},
#   {'dt': 1659478320, 'precipitation': 0},
#   {'dt': 1659478380, 'precipitation': 0},
#   {'dt': 1659478440, 'precipitation': 0},
#   {'dt': 1659478500, 'precipitation': 0},
#   {'dt': 1659478560, 'precipitation': 0},
#   {'dt': 1659478620, 'precipitation': 0},
#   {'dt': 1659478680, 'precipitation': 0},
#   {'dt': 1659478740, 'precipitation': 0},
#   {'dt': 1659478800, 'precipitation': 0},
#   {'dt': 1659478860, 'precipitation': 0},
#   {'dt': 1659478920, 'precipitation': 0},
#   {'dt': 1659478980, 'precipitation': 0},
#   {'dt': 1659479040, 'precipitation': 0},
#   {'dt': 1659479100, 'precipitation': 0},
#   {'dt': 1659479160, 'precipitation': 0},
#   {'dt': 1659479220, 'precipitation': 0},
#   {'dt': 1659479280, 'precipitation': 0},
#   {'dt': 1659479340, 'precipitation': 0},
#   {'dt': 1659479400, 'precipitation': 0},
#   {'dt': 1659479460, 'precipitation': 0},
#   {'dt': 1659479520, 'precipitation': 0},
#   {'dt': 1659479580, 'precipitation': 0},
#   {'dt': 1659479640, 'precipitation': 0},
#   {'dt': 1659479700, 'precipitation': 0},
#   {'dt': 1659479760, 'precipitation': 0}],
#  'hourly': [{'dt': 1659474000,
#    'temp': 18.35,
#    'feels_like': 18.72,
#    'pressure': 1017,
#    'humidity': 95,
#    'dew_point': 17.54,
#    'uvi': 0,
#    'clouds': 44,
#    'visibility': 10000,
#    'wind_speed': 4,
#    'wind_deg': 335,
#    'wind_gust': 7.67,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1659477600,
#    'temp': 18.39,
#    'feels_like': 18.77,
#    'pressure': 1017,
#    'humidity': 95,
#    'dew_point': 17.58,
#    'uvi': 0,
#    'clouds': 48,
#    'visibility': 10000,
#    'wind_speed': 3.23,
#    'wind_deg': 349,
#    'wind_gust': 6.05,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1659481200,
#    'temp': 18.28,
#    'feels_like': 18.64,
#    'pressure': 1017,
#    'humidity': 95,
#    'dew_point': 17.47,
#    'uvi': 0,
#    'clouds': 50,
#    'visibility': 10000,
#    'wind_speed': 2.9,
#    'wind_deg': 5,
#    'wind_gust': 4.75,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1659484800,
#    'temp': 18.03,
#    'feels_like': 18.37,
#    'pressure': 1017,
#    'humidity': 95,
#    'dew_point': 17.22,
#    'uvi': 0,
#    'clouds': 55,
#    'visibility': 10000,
#    'wind_speed': 2.45,
#    'wind_deg': 8,
#    'wind_gust': 3.42,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1659488400,
#    'temp': 17.68,
#    'feels_like': 17.96,
#    'pressure': 1016,
#    'humidity': 94,
#    'dew_point': 16.7,
#    'uvi': 0,
#    'clouds': 43,
#    'visibility': 10000,
#    'wind_speed': 2.28,
#    'wind_deg': 3,
#    'wind_gust': 2.85,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1659492000,
#    'temp': 17.33,
#    'feels_like': 17.57,
#    'pressure': 1016,
#    'humidity': 94,
#    'dew_point': 16.36,
#    'uvi': 0,
#    'clouds': 43,
#    'visibility': 10000,
#    'wind_speed': 2.14,
#    'wind_deg': 1,
#    'wind_gust': 2.77,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1659495600,
#    'temp': 16.84,
#    'feels_like': 17.03,
#    'pressure': 1016,
#    'humidity': 94,
#    'dew_point': 15.62,
#    'uvi': 0,
#    'clouds': 48,
#    'visibility': 10000,
#    'wind_speed': 1.63,
#    'wind_deg': 19,
#    'wind_gust': 1.75,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1659499200,
#    'temp': 16.68,
#    'feels_like': 16.83,
#    'pressure': 1016,
#    'humidity': 93,
#    'dew_point': 15.35,
#    'uvi': 0,
#    'clouds': 45,
#    'visibility': 10000,
#    'wind_speed': 1.51,
#    'wind_deg': 2,
#    'wind_gust': 1.59,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1659502800,
#    'temp': 16.66,
#    'feels_like': 16.81,
#    'pressure': 1016,
#    'humidity': 93,
#    'dew_point': 15.38,
#    'uvi': 0,
#    'clouds': 36,
#    'visibility': 10000,
#    'wind_speed': 1.69,
#    'wind_deg': 354,
#    'wind_gust': 1.82,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1659506400,
#    'temp': 18.09,
#    'feels_like': 18.33,
#    'pressure': 1016,
#    'humidity': 91,
#    'dew_point': 16.37,
#    'uvi': 0.31,
#    'clouds': 30,
#    'visibility': 10000,
#    'wind_speed': 1.98,
#    'wind_deg': 344,
#    'wind_gust': 2.99,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1659510000,
#    'temp': 20.02,
#    'feels_like': 20.24,
#    'pressure': 1016,
#    'humidity': 83,
#    'dew_point': 16.88,
#    'uvi': 0.96,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.64,
#    'wind_deg': 343,
#    'wind_gust': 3.21,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1659513600,
#    'temp': 22.01,
#    'feels_like': 22.12,
#    'pressure': 1016,
#    'humidity': 71,
#    'dew_point': 16.36,
#    'uvi': 2.11,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 2.97,
#    'wind_deg': 337,
#    'wind_gust': 3.04,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1659517200,
#    'temp': 23.91,
#    'feels_like': 23.95,
#    'pressure': 1016,
#    'humidity': 61,
#    'dew_point': 15.73,
#    'uvi': 3.67,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 3.71,
#    'wind_deg': 321,
#    'wind_gust': 3.26,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1659520800,
#    'temp': 24.74,
#    'feels_like': 24.76,
#    'pressure': 1016,
#    'humidity': 57,
#    'dew_point': 15.27,
#    'uvi': 5.29,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 4.35,
#    'wind_deg': 319,
#    'wind_gust': 3.54,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1659524400,
#    'temp': 25.42,
#    'feels_like': 25.4,
#    'pressure': 1016,
#    'humidity': 53,
#    'dew_point': 14.83,
#    'uvi': 6.57,
#    'clouds': 0,
#    'visibility': 10000,
#    'wind_speed': 4.59,
#    'wind_deg': 314,
#    'wind_gust': 3.36,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1659528000,
#    'temp': 25.43,
#    'feels_like': 25.39,
#    'pressure': 1016,
#    'humidity': 52,
#    'dew_point': 14.45,
#    'uvi': 7.13,
#    'clouds': 1,
#    'visibility': 10000,
#    'wind_speed': 5.33,
#    'wind_deg': 313,
#    'wind_gust': 4.09,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1659531600,
#    'temp': 25.5,
#    'feels_like': 25.44,
#    'pressure': 1016,
#    'humidity': 51,
#    'dew_point': 14.35,
#    'uvi': 6.82,
#    'clouds': 56,
#    'visibility': 10000,
#    'wind_speed': 5.41,
#    'wind_deg': 317,
#    'wind_gust': 4.54,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1659535200,
#    'temp': 25.92,
#    'feels_like': 25.87,
#    'pressure': 1015,
#    'humidity': 50,
#    'dew_point': 14.34,
#    'uvi': 5.69,
#    'clouds': 42,
#    'visibility': 10000,
#    'wind_speed': 5.03,
#    'wind_deg': 326,
#    'wind_gust': 4.56,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1659538800,
#    'temp': 26.5,
#    'feels_like': 26.5,
#    'pressure': 1014,
#    'humidity': 48,
#    'dew_point': 14.31,
#    'uvi': 4.11,
#    'clouds': 42,
#    'visibility': 10000,
#    'wind_speed': 5.06,
#    'wind_deg': 333,
#    'wind_gust': 4.79,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1659542400,
#    'temp': 26.25,
#    'feels_like': 26.25,
#    'pressure': 1014,
#    'humidity': 51,
#    'dew_point': 14.91,
#    'uvi': 2.32,
#    'clouds': 40,
#    'visibility': 10000,
#    'wind_speed': 5.81,
#    'wind_deg': 332,
#    'wind_gust': 5.62,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1659546000,
#    'temp': 24.53,
#    'feels_like': 24.58,
#    'pressure': 1014,
#    'humidity': 59,
#    'dew_point': 15.83,
#    'uvi': 1.12,
#    'clouds': 36,
#    'visibility': 10000,
#    'wind_speed': 6.85,
#    'wind_deg': 330,
#    'wind_gust': 7.3,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1659549600,
#    'temp': 22.5,
#    'feels_like': 22.61,
#    'pressure': 1014,
#    'humidity': 69,
#    'dew_point': 16.4,
#    'uvi': 0.4,
#    'clouds': 36,
#    'visibility': 10000,
#    'wind_speed': 6.61,
#    'wind_deg': 336,
#    'wind_gust': 8.29,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1659553200,
#    'temp': 20.75,
#    'feels_like': 21,
#    'pressure': 1014,
#    'humidity': 81,
#    'dew_point': 17.06,
#    'uvi': 0,
#    'clouds': 46,
#    'visibility': 10000,
#    'wind_speed': 5.23,
#    'wind_deg': 338,
#    'wind_gust': 8.75,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1659556800,
#    'temp': 18.56,
#    'feels_like': 18.93,
#    'pressure': 1015,
#    'humidity': 94,
#    'dew_point': 17.33,
#    'uvi': 0,
#    'clouds': 48,
#    'visibility': 10000,
#    'wind_speed': 4.03,
#    'wind_deg': 339,
#    'wind_gust': 8.21,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1659560400,
#    'temp': 18.21,
#    'feels_like': 18.57,
#    'pressure': 1015,
#    'humidity': 95,
#    'dew_point': 17.22,
#    'uvi': 0,
#    'clouds': 60,
#    'visibility': 10000,
#    'wind_speed': 3.89,
#    'wind_deg': 340,
#    'wind_gust': 7.81,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1659564000,
#    'temp': 18.08,
#    'feels_like': 18.45,
#    'pressure': 1016,
#    'humidity': 96,
#    'dew_point': 17.13,
#    'uvi': 0,
#    'clouds': 70,
#    'visibility': 10000,
#    'wind_speed': 4.08,
#    'wind_deg': 338,
#    'wind_gust': 8.15,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1659567600,
#    'temp': 18.01,
#    'feels_like': 18.35,
#    'pressure': 1015,
#    'humidity': 95,
#    'dew_point': 16.99,
#    'uvi': 0,
#    'clouds': 76,
#    'visibility': 10000,
#    'wind_speed': 4.14,
#    'wind_deg': 342,
#    'wind_gust': 8.13,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1659571200,
#    'temp': 17.55,
#    'feels_like': 17.79,
#    'pressure': 1016,
#    'humidity': 93,
#    'dew_point': 16.24,
#    'uvi': 0,
#    'clouds': 79,
#    'visibility': 10000,
#    'wind_speed': 3.52,
#    'wind_deg': 347,
#    'wind_gust': 6.95,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1659574800,
#    'temp': 16.98,
#    'feels_like': 17.11,
#    'pressure': 1016,
#    'humidity': 91,
#    'dew_point': 15.34,
#    'uvi': 0,
#    'clouds': 86,
#    'visibility': 10000,
#    'wind_speed': 3.39,
#    'wind_deg': 347,
#    'wind_gust': 6.28,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1659578400,
#    'temp': 16.38,
#    'feels_like': 16.45,
#    'pressure': 1016,
#    'humidity': 91,
#    'dew_point': 14.57,
#    'uvi': 0,
#    'clouds': 49,
#    'visibility': 10000,
#    'wind_speed': 3.19,
#    'wind_deg': 351,
#    'wind_gust': 5.36,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1659582000,
#    'temp': 16,
#    'feels_like': 16.01,
#    'pressure': 1016,
#    'humidity': 90,
#    'dew_point': 14.2,
#    'uvi': 0,
#    'clouds': 34,
#    'visibility': 10000,
#    'wind_speed': 3.62,
#    'wind_deg': 350,
#    'wind_gust': 6.25,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1659585600,
#    'temp': 15.65,
#    'feels_like': 15.59,
#    'pressure': 1016,
#    'humidity': 89,
#    'dew_point': 13.59,
#    'uvi': 0,
#    'clouds': 26,
#    'visibility': 10000,
#    'wind_speed': 3.61,
#    'wind_deg': 351,
#    'wind_gust': 6.35,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1659589200,
#    'temp': 15.39,
#    'feels_like': 15.28,
#    'pressure': 1016,
#    'humidity': 88,
#    'dew_point': 13.04,
#    'uvi': 0,
#    'clouds': 22,
#    'visibility': 10000,
#    'wind_speed': 3.8,
#    'wind_deg': 349,
#    'wind_gust': 6.72,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1659592800,
#    'temp': 16.6,
#    'feels_like': 16.4,
#    'pressure': 1016,
#    'humidity': 80,
#    'dew_point': 13.03,
#    'uvi': 0.3,
#    'clouds': 19,
#    'visibility': 10000,
#    'wind_speed': 3.91,
#    'wind_deg': 348,
#    'wind_gust': 7.32,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1659596400,
#    'temp': 18.75,
#    'feels_like': 18.43,
#    'pressure': 1017,
#    'humidity': 67,
#    'dew_point': 12.46,
#    'uvi': 0.94,
#    'clouds': 34,
#    'visibility': 10000,
#    'wind_speed': 5.22,
#    'wind_deg': 344,
#    'wind_gust': 6.8,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1659600000,
#    'temp': 20.29,
#    'feels_like': 19.89,
#    'pressure': 1017,
#    'humidity': 58,
#    'dew_point': 11.51,
#    'uvi': 2.09,
#    'clouds': 32,
#    'visibility': 10000,
#    'wind_speed': 5.67,
#    'wind_deg': 336,
#    'wind_gust': 6.4,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1659603600,
#    'temp': 21.07,
#    'feels_like': 20.64,
#    'pressure': 1017,
#    'humidity': 54,
#    'dew_point': 11.32,
#    'uvi': 3.66,
#    'clouds': 33,
#    'visibility': 10000,
#    'wind_speed': 6,
#    'wind_deg': 328,
#    'wind_gust': 6.31,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1659607200,
#    'temp': 21.63,
#    'feels_like': 21.23,
#    'pressure': 1017,
#    'humidity': 53,
#    'dew_point': 11.28,
#    'uvi': 5.34,
#    'clouds': 27,
#    'visibility': 10000,
#    'wind_speed': 6.27,
#    'wind_deg': 322,
#    'wind_gust': 6.15,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1659610800,
#    'temp': 21.9,
#    'feels_like': 21.5,
#    'pressure': 1017,
#    'humidity': 52,
#    'dew_point': 11.32,
#    'uvi': 6.64,
#    'clouds': 22,
#    'visibility': 10000,
#    'wind_speed': 6.31,
#    'wind_deg': 320,
#    'wind_gust': 5.93,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1659614400,
#    'temp': 22.02,
#    'feels_like': 21.64,
#    'pressure': 1017,
#    'humidity': 52,
#    'dew_point': 11.32,
#    'uvi': 7.21,
#    'clouds': 20,
#    'visibility': 10000,
#    'wind_speed': 6.6,
#    'wind_deg': 320,
#    'wind_gust': 6.04,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1659618000,
#    'temp': 21.91,
#    'feels_like': 21.51,
#    'pressure': 1018,
#    'humidity': 52,
#    'dew_point': 11.44,
#    'uvi': 6.85,
#    'clouds': 54,
#    'visibility': 10000,
#    'wind_speed': 7.31,
#    'wind_deg': 320,
#    'wind_gust': 6.8,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1659621600,
#    'temp': 21.55,
#    'feels_like': 21.17,
#    'pressure': 1018,
#    'humidity': 54,
#    'dew_point': 11.45,
#    'uvi': 5.72,
#    'clouds': 66,
#    'visibility': 10000,
#    'wind_speed': 7.01,
#    'wind_deg': 319,
#    'wind_gust': 6.69,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1659625200,
#    'temp': 21.16,
#    'feels_like': 20.74,
#    'pressure': 1018,
#    'humidity': 54,
#    'dew_point': 11.28,
#    'uvi': 4.12,
#    'clouds': 65,
#    'visibility': 10000,
#    'wind_speed': 6.73,
#    'wind_deg': 318,
#    'wind_gust': 6.84,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1659628800,
#    'temp': 20.37,
#    'feels_like': 19.98,
#    'pressure': 1018,
#    'humidity': 58,
#    'dew_point': 11.51,
#    'uvi': 2.21,
#    'clouds': 70,
#    'visibility': 10000,
#    'wind_speed': 6.47,
#    'wind_deg': 321,
#    'wind_gust': 7.01,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1659632400,
#    'temp': 19.79,
#    'feels_like': 19.42,
#    'pressure': 1018,
#    'humidity': 61,
#    'dew_point': 11.82,
#    'uvi': 1.07,
#    'clouds': 73,
#    'visibility': 10000,
#    'wind_speed': 6.58,
#    'wind_deg': 328,
#    'wind_gust': 7.34,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1659636000,
#    'temp': 18.92,
#    'feels_like': 18.56,
#    'pressure': 1018,
#    'humidity': 65,
#    'dew_point': 12.1,
#    'uvi': 0.38,
#    'clouds': 73,
#    'visibility': 10000,
#    'wind_speed': 6.91,
#    'wind_deg': 335,
#    'wind_gust': 8.03,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1659639600,
#    'temp': 17.88,
#    'feels_like': 17.58,
#    'pressure': 1018,
#    'humidity': 71,
#    'dew_point': 12.51,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6,
#    'wind_deg': 337,
#    'wind_gust': 8.49,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1659643200,
#    'temp': 16.89,
#    'feels_like': 16.57,
#    'pressure': 1019,
#    'humidity': 74,
#    'dew_point': 11.99,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.53,
#    'wind_deg': 341,
#    'wind_gust': 9.17,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0}],
#  'daily': [{'dt': 1659441600,
#    'sunrise': 1659415270,
#    'sunset': 1659469402,
#    'moonrise': 1659432600,
#    'moonset': 1659477300,
#    'moon_phase': 0.15,
#    'temp': {'day': 26.03,
#     'min': 15.66,
#     'max': 27.71,
#     'night': 18.35,
#     'eve': 23.36,
#     'morn': 17.17},
#    'feels_like': {'day': 26.03, 'night': 18.72, 'eve': 23.5, 'morn': 17.24},
#    'pressure': 1018,
#    'humidity': 53,
#    'dew_point': 15.2,
#    'wind_speed': 5.74,
#    'wind_deg': 334,
#    'wind_gust': 8.24,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 100,
#    'pop': 0,
#    'uvi': 7.44},
#   {'dt': 1659528000,
#    'sunrise': 1659501751,
#    'sunset': 1659555713,
#    'moonrise': 1659523260,
#    'moonset': 0,
#    'moon_phase': 0.18,
#    'temp': {'day': 25.43,
#     'min': 16.66,
#     'max': 26.5,
#     'night': 18.21,
#     'eve': 22.5,
#     'morn': 18.09},
#    'feels_like': {'day': 25.39, 'night': 18.57, 'eve': 22.61, 'morn': 18.33},
#    'pressure': 1016,
#    'humidity': 52,
#    'dew_point': 14.45,
#    'wind_speed': 6.85,
#    'wind_deg': 330,
#    'wind_gust': 8.75,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 1,
#    'pop': 0,
#    'uvi': 7.13},
#   {'dt': 1659614400,
#    'sunrise': 1659588232,
#    'sunset': 1659642023,
#    'moonrise': 1659614100,
#    'moonset': 1659564660,
#    'moon_phase': 0.21,
#    'temp': {'day': 22.02,
#     'min': 15.39,
#     'max': 22.02,
#     'night': 16.41,
#     'eve': 18.92,
#     'morn': 16.6},
#    'feels_like': {'day': 21.64, 'night': 15.96, 'eve': 18.56, 'morn': 16.4},
#    'pressure': 1017,
#    'humidity': 52,
#    'dew_point': 11.32,
#    'wind_speed': 7.31,
#    'wind_deg': 320,
#    'wind_gust': 9.17,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': 20,
#    'pop': 0,
#    'uvi': 7.21},
#   {'dt': 1659700800,
#    'sunrise': 1659674714,
#    'sunset': 1659728332,
#    'moonrise': 1659705180,
#    'moonset': 1659652140,
#    'moon_phase': 0.25,
#    'temp': {'day': 24.08,
#     'min': 11.92,
#     'max': 24.58,
#     'night': 13.68,
#     'eve': 21.57,
#     'morn': 14.33},
#    'feels_like': {'day': 23.46, 'night': 12.62, 'eve': 20.67, 'morn': 13.67},
#    'pressure': 1023,
#    'humidity': 35,
#    'dew_point': 7.53,
#    'wind_speed': 7.22,
#    'wind_deg': 14,
#    'wind_gust': 11.44,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 6,
#    'pop': 0,
#    'uvi': 6.81},
#   {'dt': 1659787200,
#    'sunrise': 1659761196,
#    'sunset': 1659814639,
#    'moonrise': 1659796440,
#    'moonset': 1659739860,
#    'moon_phase': 0.28,
#    'temp': {'day': 27.12,
#     'min': 12.27,
#     'max': 28.73,
#     'night': 17.27,
#     'eve': 24.3,
#     'morn': 14.29},
#    'feels_like': {'day': 26.11, 'night': 16.49, 'eve': 23.6, 'morn': 12.9},
#    'pressure': 1022,
#    'humidity': 18,
#    'dew_point': -0.12,
#    'wind_speed': 8.5,
#    'wind_deg': 35,
#    'wind_gust': 13.62,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 98,
#    'pop': 0,
#    'uvi': 6.37},
#   {'dt': 1659873600,
#    'sunrise': 1659847678,
#    'sunset': 1659900944,
#    'moonrise': 1659887820,
#    'moonset': 1659827940,
#    'moon_phase': 0.32,
#    'temp': {'day': 28.45,
#     'min': 13.73,
#     'max': 29.61,
#     'night': 19.57,
#     'eve': 25.32,
#     'morn': 14.59},
#    'feels_like': {'day': 27.11, 'night': 18.99, 'eve': 24.74, 'morn': 13.51},
#    'pressure': 1019,
#    'humidity': 22,
#    'dew_point': 4.26,
#    'wind_speed': 7.75,
#    'wind_deg': 33,
#    'wind_gust': 14.44,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': 50,
#    'pop': 0,
#    'uvi': 6.6},
#   {'dt': 1659960000,
#    'sunrise': 1659934161,
#    'sunset': 1659987248,
#    'moonrise': 1659978840,
#    'moonset': 1659916680,
#    'moon_phase': 0.36,
#    'temp': {'day': 28.89,
#     'min': 16.02,
#     'max': 28.89,
#     'night': 18.36,
#     'eve': 25.22,
#     'morn': 16.25},
#    'feels_like': {'day': 27.58, 'night': 17.82, 'eve': 24.71, 'morn': 15.39},
#    'pressure': 1021,
#    'humidity': 26,
#    'dew_point': 6.9,
#    'wind_speed': 8.3,
#    'wind_deg': 32,
#    'wind_gust': 13.53,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 6,
#    'pop': 0,
#    'uvi': 7},
#   {'dt': 1660046400,
#    'sunrise': 1660020645,
#    'sunset': 1660073550,
#    'moonrise': 1660069200,
#    'moonset': 1660006260,
#    'moon_phase': 0.4,
#    'temp': {'day': 30.95,
#     'min': 15.92,
#     'max': 30.95,
#     'night': 19.96,
#     'eve': 27.63,
#     'morn': 16.27},
#    'feels_like': {'day': 29.36, 'night': 19.47, 'eve': 27.07, 'morn': 15.75},
#    'pressure': 1017,
#    'humidity': 26,
#    'dew_point': 8.65,
#    'wind_speed': 7.12,
#    'wind_deg': 27,
#    'wind_gust': 11.47,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 1,
#    'pop': 0,
#    'uvi': 7}],
#  'city': 'Mont Saint Michel'}

# %%
weather_json.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'current', 'minutely', 'hourly', 'daily', 'city'])

# %%
len(weather_json['daily'])
# Out:
# 8

# %%
weather_json['daily'][0].keys()
# Out:
# dict_keys(['dt', 'sunrise', 'sunset', 'moonrise', 'moonset', 'moon_phase', 'temp', 'feels_like', 'pressure', 'humidity', 'dew_point', 'wind_speed', 'wind_deg', 'wind_gust', 'weather', 'clouds', 'pop', 'uvi'])

# %% [markdown]
# The dates are in UNIX (=POSIX) format (number of seconds since 1st January 1970).
# To convert it to datetime format we can use datetime.fromtimestamp method :

# %%
from datetime import datetime
date_example = datetime.fromtimestamp(weather_json['current']['dt'])
print(date_example)
# Out:
# 2022-08-02 21:35:27

# %%
first_day_example = datetime.fromtimestamp(weather_json['daily'][0]['dt'])
last_day_example = datetime.fromtimestamp(weather_json['daily'][-1]['dt'])
print(first_day_example)
print(last_day_example)
# Out:
# 2022-08-02 12:00:00
# 2022-08-09 12:00:00

# %% [markdown]
# We see that the 'daily' information is available from current day to the day D+7 included.
# Reminder : the time is set in UTC (Paris is UTC+1)

# %%
weather_0 = {key:weather_json[key] for key in ['city','daily']}
weather_0
# Out:
# {'city': 'Mont Saint Michel',
#  'daily': [{'dt': 1659441600,
#    'sunrise': 1659415270,
#    'sunset': 1659469402,
#    'moonrise': 1659432600,
#    'moonset': 1659477300,
#    'moon_phase': 0.15,
#    'temp': {'day': 26.03,
#     'min': 15.66,
#     'max': 27.71,
#     'night': 18.35,
#     'eve': 23.36,
#     'morn': 17.17},
#    'feels_like': {'day': 26.03, 'night': 18.72, 'eve': 23.5, 'morn': 17.24},
#    'pressure': 1018,
#    'humidity': 53,
#    'dew_point': 15.2,
#    'wind_speed': 5.74,
#    'wind_deg': 334,
#    'wind_gust': 8.24,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 100,
#    'pop': 0,
#    'uvi': 7.44},
#   {'dt': 1659528000,
#    'sunrise': 1659501751,
#    'sunset': 1659555713,
#    'moonrise': 1659523260,
#    'moonset': 0,
#    'moon_phase': 0.18,
#    'temp': {'day': 25.43,
#     'min': 16.66,
#     'max': 26.5,
#     'night': 18.21,
#     'eve': 22.5,
#     'morn': 18.09},
#    'feels_like': {'day': 25.39, 'night': 18.57, 'eve': 22.61, 'morn': 18.33},
#    'pressure': 1016,
#    'humidity': 52,
#    'dew_point': 14.45,
#    'wind_speed': 6.85,
#    'wind_deg': 330,
#    'wind_gust': 8.75,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 1,
#    'pop': 0,
#    'uvi': 7.13},
#   {'dt': 1659614400,
#    'sunrise': 1659588232,
#    'sunset': 1659642023,
#    'moonrise': 1659614100,
#    'moonset': 1659564660,
#    'moon_phase': 0.21,
#    'temp': {'day': 22.02,
#     'min': 15.39,
#     'max': 22.02,
#     'night': 16.41,
#     'eve': 18.92,
#     'morn': 16.6},
#    'feels_like': {'day': 21.64, 'night': 15.96, 'eve': 18.56, 'morn': 16.4},
#    'pressure': 1017,
#    'humidity': 52,
#    'dew_point': 11.32,
#    'wind_speed': 7.31,
#    'wind_deg': 320,
#    'wind_gust': 9.17,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': 20,
#    'pop': 0,
#    'uvi': 7.21},
#   {'dt': 1659700800,
#    'sunrise': 1659674714,
#    'sunset': 1659728332,
#    'moonrise': 1659705180,
#    'moonset': 1659652140,
#    'moon_phase': 0.25,
#    'temp': {'day': 24.08,
#     'min': 11.92,
#     'max': 24.58,
#     'night': 13.68,
#     'eve': 21.57,
#     'morn': 14.33},
#    'feels_like': {'day': 23.46, 'night': 12.62, 'eve': 20.67, 'morn': 13.67},
#    'pressure': 1023,
#    'humidity': 35,
#    'dew_point': 7.53,
#    'wind_speed': 7.22,
#    'wind_deg': 14,
#    'wind_gust': 11.44,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 6,
#    'pop': 0,
#    'uvi': 6.81},
#   {'dt': 1659787200,
#    'sunrise': 1659761196,
#    'sunset': 1659814639,
#    'moonrise': 1659796440,
#    'moonset': 1659739860,
#    'moon_phase': 0.28,
#    'temp': {'day': 27.12,
#     'min': 12.27,
#     'max': 28.73,
#     'night': 17.27,
#     'eve': 24.3,
#     'morn': 14.29},
#    'feels_like': {'day': 26.11, 'night': 16.49, 'eve': 23.6, 'morn': 12.9},
#    'pressure': 1022,
#    'humidity': 18,
#    'dew_point': -0.12,
#    'wind_speed': 8.5,
#    'wind_deg': 35,
#    'wind_gust': 13.62,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': 98,
#    'pop': 0,
#    'uvi': 6.37},
#   {'dt': 1659873600,
#    'sunrise': 1659847678,
#    'sunset': 1659900944,
#    'moonrise': 1659887820,
#    'moonset': 1659827940,
#    'moon_phase': 0.32,
#    'temp': {'day': 28.45,
#     'min': 13.73,
#     'max': 29.61,
#     'night': 19.57,
#     'eve': 25.32,
#     'morn': 14.59},
#    'feels_like': {'day': 27.11, 'night': 18.99, 'eve': 24.74, 'morn': 13.51},
#    'pressure': 1019,
#    'humidity': 22,
#    'dew_point': 4.26,
#    'wind_speed': 7.75,
#    'wind_deg': 33,
#    'wind_gust': 14.44,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': 50,
#    'pop': 0,
#    'uvi': 6.6},
#   {'dt': 1659960000,
#    'sunrise': 1659934161,
#    'sunset': 1659987248,
#    'moonrise': 1659978840,
#    'moonset': 1659916680,
#    'moon_phase': 0.36,
#    'temp': {'day': 28.89,
#     'min': 16.02,
#     'max': 28.89,
#     'night': 18.36,
#     'eve': 25.22,
#     'morn': 16.25},
#    'feels_like': {'day': 27.58, 'night': 17.82, 'eve': 24.71, 'morn': 15.39},
#    'pressure': 1021,
#    'humidity': 26,
#    'dew_point': 6.9,
#    'wind_speed': 8.3,
#    'wind_deg': 32,
#    'wind_gust': 13.53,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 6,
#    'pop': 0,
#    'uvi': 7},
#   {'dt': 1660046400,
#    'sunrise': 1660020645,
#    'sunset': 1660073550,
#    'moonrise': 1660069200,
#    'moonset': 1660006260,
#    'moon_phase': 0.4,
#    'temp': {'day': 30.95,
#     'min': 15.92,
#     'max': 30.95,
#     'night': 19.96,
#     'eve': 27.63,
#     'morn': 16.27},
#    'feels_like': {'day': 29.36, 'night': 19.47, 'eve': 27.07, 'morn': 15.75},
#    'pressure': 1017,
#    'humidity': 26,
#    'dew_point': 8.65,
#    'wind_speed': 7.12,
#    'wind_deg': 27,
#    'wind_gust': 11.47,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 1,
#    'pop': 0,
#    'uvi': 7}]}

# %%
weather_0['daily'][0]['feels_like']
# Out:
# {'day': 26.03, 'night': 18.72, 'eve': 23.5, 'morn': 17.24}

# %%
weather_0_df = pd.DataFrame(weather_0)
weather_0_df
# Out:
#                 city                                              daily
# 0  Mont Saint Michel  {'dt': 1659441600, 'sunrise': 1659415270, 'sun...
# 1  Mont Saint Michel  {'dt': 1659528000, 'sunrise': 1659501751, 'sun...
# 2  Mont Saint Michel  {'dt': 1659614400, 'sunrise': 1659588232, 'sun...
# 3  Mont Saint Michel  {'dt': 1659700800, 'sunrise': 1659674714, 'sun...
# 4  Mont Saint Michel  {'dt': 1659787200, 'sunrise': 1659761196, 'sun...
# 5  Mont Saint Michel  {'dt': 1659873600, 'sunrise': 1659847678, 'sun...
# 6  Mont Saint Michel  {'dt': 1659960000, 'sunrise': 1659934161, 'sun...
# 7  Mont Saint Michel  {'dt': 1660046400, 'sunrise': 1660020645, 'sun...

# %%
list(weather_0.keys())
# Out:
# ['city', 'daily']

# %%
weather_0_df = pd.json_normalize(weather_0, record_path = ['daily'], meta = [key for key in weather_0.keys() if key != 'daily'])
weather_0_df

# %%
len(pd.json_normalize(weather_0, record_path = ['daily'])['weather'][0])

# %%
weather_0_df['weather'].explode()

# %%
pd.json_normalize(weather_0_df['weather'].explode())

# %%
weather_0_df = pd.concat(
    [
        weather_0_df.drop(columns = ['weather']), 
        pd.json_normalize(weather_0_df['weather'].explode()).add_prefix('weather.')
    ], 
    axis = 1)

# %%
weather_0_df

# %%
city_df_0 = geolocs_df.merge(weather_0_df, on = ['city'])
city_df_0

# %% [markdown]
# ### Generalization to the 35 cities - storing all localization and weather data in a single dataframe

# %%
city_dataframes = []
for i, city  in enumerate(cities):    
    lat, lon = (geolocs_df[_][i] for _ in ['lat','lon'])
    r = requests.get(f'https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&appid={api_key}&units={units}')
    weather_json = r.json() #We consider the first search result as the most relevant one
    weather_json['city']= city
    weather_json = {key:weather_json[key] for key in ['city','daily']}
    
    weather_df = pd.json_normalize(weather_json, record_path = ['daily'], meta = [key for key in weather_0.keys() if key != 'daily'])
    weather_df = pd.concat(
    [
        weather_df.drop(columns = ['weather']), 
        pd.json_normalize(weather_df['weather'].explode()).add_prefix('weather.')
    ], 
    axis = 1)
    
    city_df = geolocs_df.merge(weather_df, on = ['city'])
    
    city_dataframes.append(city_df)
    
city_dataframes[1]

# %%
cities_df = pd.concat(city_dataframes, axis = 0)
cities_df

# %% [markdown]
# ### Selecting criterias and saving csv file

# %%
import numpy as np
criterias = {
    'feels_like.day': np.mean,
    'pop': np.mean
}

# %%
cities_df_grouped = cities_df.groupby('city').agg(criterias)
ideal_temperature = 30
cities_df_grouped['delta_with_ideal_temp'] = cities_df_grouped['feels_like.day'].apply(lambda temp : round(abs(temp - ideal_temperature)))
cities_df_grouped['pop_%'] = cities_df_grouped['pop']*100 

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
scaled_criterias = pd.DataFrame(sc.fit_transform(cities_df_grouped.iloc[:,2:]), index = cities_df_grouped.index, columns = ['delta_temp_scaled', 'pop_scaled']) 
scaled_criterias['score_to_minimize'] = scaled_criterias['delta_temp_scaled'] + scaled_criterias['pop_scaled']

cities_df_grouped = pd.concat([cities_df_grouped, scaled_criterias], axis = 1)
cities_df_grouped = cities_df_grouped.sort_values(['score_to_minimize'], ascending = True).reset_index(drop = False)
cities_df_grouped.insert(0, 'id', cities_df_grouped.index)
cities_df_grouped['rank'] = cities_df_grouped.index + 1
cities_df_grouped

# %%
cities_df_grouped.to_csv('weather_data.csv', index = False)
