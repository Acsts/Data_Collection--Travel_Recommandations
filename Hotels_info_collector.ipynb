# %%
#!pip install scrapy

# %%
import pandas as pd
import numpy as np
import scrapy
import os
import logging
from scrapy.crawler import CrawlerProcess
import time
import json

# %%
weather_df = pd.read_csv('weather_data.csv')
weather_df
# Out:
#     id                          city  feels_like.day      pop  \
# 0    0                     Eguisheim        30.43625  0.12375
# 1    1                      Besancon        30.28750  0.17500
# 2    2                    Strasbourg        30.63875  0.08375
# 3    3                         Dijon        31.17000  0.08875
# 4    4                        Cassis        30.25500  0.19250
# 5    5                     Marseille        30.36500  0.19375
# 6    6                         Rouen        28.34375  0.01125
# 7    7                        Colmar        30.60375  0.12000
# 8    8                        Annecy        30.20000  0.22375
# 9    9                 Aigues Mortes        30.45250  0.24375
# 10  10             Mont Saint Michel        26.59625  0.00000
# 11  11            Bormes les Mimosas        31.14750  0.18500
# 12  12                         Lille        26.95375  0.00500
# 13  13      Saintes Maries de la mer        29.05875  0.19000
# 14  14                        Amiens        27.40125  0.03750
# 15  15  Chateau du Haut Koenigsbourg        27.47750  0.09375
# 16  16                          Lyon        32.18125  0.19125
# 17  17                         Paris        28.49000  0.20250
# 18  18                     Collioure        31.30500  0.30750
# 19  19                   La Rochelle        27.40625  0.19625
# 20  20                      Grenoble        33.10750  0.24375
# 21  21               Aix en Provence        32.77750  0.24375
# 22  22              Gorges du Verdon        29.08500  0.42750
# 23  23                      Le Havre        22.89000  0.00000
# 24  24                       St Malo        23.33250  0.00000
# 25  25                        Bayeux        23.35375  0.00000
# 26  26                      Toulouse        33.07250  0.39125
# 27  27                          Uzes        34.00875  0.32875
# 28  28                     Montauban        33.23000  0.45250
# 29  29                       Avignon        35.12000  0.28250
# 30  30                         Nimes        34.72750  0.30500
# 31  31                   Carcassonne        33.92125  0.51750
# 32  32                        Ariege        26.88250  0.61875
# 33  33                       Bayonne        25.84000  0.67500
# 34  34                      Biarritz        24.89250  0.66000
#
#     delta_with_ideal_temp   pop_%  delta_temp_scaled  pop_scaled  \
# 0                       0  12.375          -1.288998   -0.568045
# 1                       0  17.500          -1.288998   -0.291162
# 2                       1   8.375          -0.793230   -0.784149
# 3                       1   8.875          -0.793230   -0.757136
# 4                       0  19.250          -1.288998   -0.196616
# 5                       0  19.375          -1.288998   -0.189863
# 6                       2   1.125          -0.297461   -1.175838
# 7                       1  12.000          -0.793230   -0.588305
# 8                       0  22.375          -1.288998   -0.027785
# 9                       0  24.375          -1.288998    0.080267
# 10                      3   0.000           0.198307   -1.236617
# 11                      1  18.500          -0.793230   -0.237136
# 12                      3   0.500           0.198307   -1.209604
# 13                      1  19.000          -0.793230   -0.210123
# 14                      3   3.750           0.198307   -1.034020
# 15                      3   9.375           0.198307   -0.730123
# 16                      2  19.125          -0.297461   -0.203369
# 17                      2  20.250          -0.297461   -0.142590
# 18                      1  30.750          -0.793230    0.424683
# 19                      3  19.625           0.198307   -0.176356
# 20                      3  24.375           0.198307    0.080267
# 21                      3  24.375           0.198307    0.080267
# 22                      1  42.750          -0.793230    1.072996
# 23                      7   0.000           2.181382   -1.236617
# 24                      7   0.000           2.181382   -1.236617
# 25                      7   0.000           2.181382   -1.236617
# 26                      3  39.125           0.198307    0.877151
# 27                      4  32.875           0.694076    0.539488
# 28                      3  45.250           0.198307    1.208061
# 29                      5  28.250           1.189845    0.289618
# 30                      5  30.500           1.189845    0.411177
# 31                      4  51.750           0.694076    1.559230
# 32                      3  61.875           0.198307    2.106243
# 33                      4  67.500           0.694076    2.410140
# 34                      5  66.000           1.189845    2.329101
#
#     score_to_minimize  rank
# 0           -1.857044     1
# 1           -1.580160     2
# 2           -1.577379     3
# 3           -1.550366     4
# 4           -1.485615     5
# 5           -1.478861     6
# 6           -1.473299     7
# 7           -1.381535     8
# 8           -1.316783     9
# 9           -1.208731    10
# 10          -1.038310    11
# 11          -1.030365    12
# 12          -1.011297    13
# 13          -1.003352    14
# 14          -0.835712    15
# 15          -0.531816    16
# 16          -0.500831    17
# 17          -0.440051    18
# 18          -0.368547    19
# 19           0.021951    20
# 20           0.278575    21
# 21           0.278575    22
# 22           0.279766    23
# 23           0.944765    24
# 24           0.944765    25
# 25           0.944765    26
# 26           1.075459    27
# 27           1.233565    28
# 28           1.406368    29
# 29           1.479463    30
# 30           1.601021    31
# 31           2.253306    32
# 32           2.304551    33
# 33           3.104216    34
# 34           3.518945    35

# %%
top_cities = weather_df['city'].to_list()[:5]
top_cities
# Out:
# ['Eguisheim', 'Besancon', 'Strasbourg', 'Dijon', 'Cassis']

# %%
HOTELS_NB = 20

class HotelsInfoSpider(scrapy.Spider):
    # Name of your spider
    name = "Hotels_Scraping"

    # Starting URL
    start_urls = [f'https://www.booking.com/searchresults.fr.html?ss={city}' for city in top_cities]

    def start_requests(self): # overriding the default start_requests method to keep track of the city as metadata
        for url, city in zip(self.start_urls, top_cities):
            yield scrapy.Request(url, meta={'city': city})
    
    # Parse method for searching most recommended hotels in each city
    def parse(self, response):
        for link in response.css('h3 a[data-testid="title-link"]')[:HOTELS_NB]:
            hotel_url = link.attrib["href"]
            yield response.follow(hotel_url, callback=self.parse_hotel, meta={'city': response.meta['city']}) # keeping track of the city metadata for each hotel
    
    # Parse method for collecting informations on each hotel
    def parse_hotel(self, response):
        yield {
            'city' : response.meta['city'],
            'hotel_name' : ''.join(response.css('div.hp__hotel-title h2::text').getall()), # some texts contain linebreaks interpreted as separators 
            'booking_url' : response.url,
            'lat_lon coordinates' : response.css('a#hotel_sidebar_static_map').attrib['data-atlas-latlng'],
            'booking_reviews_score' : response.css('div[data-testid="review-score-component"] div:first-child::text').get(), 
            'description' : response.css('#property_description_content p::text').getall() # getting all paragraphs except the two first ones 
                                                                                                          # (which are incentives to login booking.com writes to users)
        }

# Name of the file where the results will be saved
filename = "top_hotels.json"

# If file already exists, delete it before crawling (because Scrapy will 
# concatenate the last and new results otherwise)
if filename in os.listdir('src/'):
        os.remove('src/' + filename)

# Declare a new CrawlerProcess with some settings
## USER_AGENT => Simulates a browser on an OS
## LOG_LEVEL => Minimal Level of Log 
## FEEDS => Where the file will be stored 
## More info on built-in settings => https://docs.scrapy.org/en/latest/topics/settings.html?highlight=settings#settings
process = CrawlerProcess(settings = {
    'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
    'LOG_LEVEL': logging.INFO,
    "FEEDS": {
        'src/' + filename: {"format": "json"},
    }
    #"FEED_EXPORT_ENCODING" : 'utf-8'
    #"AUTOTHROTTLE_ENABLED": True  # AutoThrottle Here!
    #"ROBOTSTXT_OBEY" : False, 
    #"COOKIES_ENABLED" : True,
    #"CONCURRENT_REQUESTS" : 1,
    #"DOWNLOAD_DELAY" : 1
    #"BOT_NAME" : "eve"
})

# Start the crawling using the spider you defined above
process.crawl(HotelsInfoSpider)
process.start()
# Out:
# 2022-08-03 19:01:50 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2022-08-03 19:01:50 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.4.0, Python 3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) - [GCC 9.4.0], pyOpenSSL 22.0.0 (OpenSSL 1.1.1l  24 Aug 2021), cryptography 36.0.1, Platform Linux-5.4.188+-x86_64-with-glibc2.31
# 2022-08-03 19:01:50 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20,
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'}
# 2022-08-03 19:01:50 [scrapy.extensions.telnet] INFO: Telnet Password: f0fd2ff2b58a794b
# 2022-08-03 19:01:50 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2022-08-03 19:01:50 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-08-03 19:01:50 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-08-03 19:01:50 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-08-03 19:01:50 [scrapy.core.engine] INFO: Spider opened
# 2022-08-03 19:01:50 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-08-03 19:01:50 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-08-03 19:02:19 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-08-03 19:02:19 [scrapy.extensions.feedexport] INFO: Stored json feed (100 items) in: src/top_hotels.json
# 2022-08-03 19:02:19 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 111129,
#  'downloader/request_count': 105,
#  'downloader/request_method_count/GET': 105,
#  'downloader/response_bytes': 23301901,
#  'downloader/response_count': 105,
#  'downloader/response_status_count/200': 105,
#  'elapsed_time_seconds': 28.785001,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 8, 3, 19, 2, 19, 722274),
#  'httpcompression/response_bytes': 141245470,
#  'httpcompression/response_count': 105,
#  'item_scraped_count': 100,
#  'log_count/INFO': 11,
#  'memusage/max': 134017024,
#  'memusage/startup': 134017024,
#  'request_depth_max': 1,
#  'response_received_count': 105,
#  'scheduler/dequeued': 105,
#  'scheduler/dequeued/memory': 105,
#  'scheduler/enqueued': 105,
#  'scheduler/enqueued/memory': 105,
#  'start_time': datetime.datetime(2022, 8, 3, 19, 1, 50, 937273)}
# 2022-08-03 19:02:19 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
with open("src/top_hotels.json", 'r') as top_hotels_file:
    top_hotels_df = pd.DataFrame(json.load(top_hotels_file))
top_hotels_df
# Out:
#         city                                   hotel_name  \
# 0   Besancon               \nibis Besançon Centre Ville\n
# 1   Besancon                       \nContact Hôtel Foch\n
# 2   Besancon  \nPremiere Classe Besancon Ecole Valentin\n
# 3   Besancon            \nAPPARTEMENT CENTRE HISTORIQUE\n
# 4   Besancon                             \nHotel Vauban\n
# ..       ...                                          ...
# 95  Besancon                           \nHôtel de Paris\n
# 96  Besancon             \nMercure Besancon Parc Micaud\n
# 97  Besancon                   \nBest Western Citadelle\n
# 98  Besancon                     \nHôtel AKENA BESANCON\n
# 99  Besancon                     \nibis Styles Besançon\n
#
#                                           booking_url     lat_lon coordinates  \
# 0   https://www.booking.com/hotel/fr/ibis-besancon...  47.24045605,6.02599533
# 1   https://www.booking.com/hotel/fr/foch-besancon...  47.24619696,6.02335095
# 2   https://www.booking.com/hotel/fr/premiere-clas...  47.27044104,5.99827230
# 3   https://www.booking.com/hotel/fr/appartement-c...  47.23432450,6.02773470
# 4   https://www.booking.com/hotel/fr/vauban-besanc...  47.23986296,6.02139884
# ..                                                ...                     ...
# 95  https://www.booking.com/hotel/fr/de-paris-besa...  47.23856537,6.02532506
# 96  https://www.booking.com/hotel/fr/besancon-parc...  47.24228752,6.03179455
# 97  https://www.booking.com/hotel/fr/bestwesternci...  47.23154100,6.02658033
# 98  https://www.booking.com/hotel/fr/akena-besanco...  47.23547525,5.90008540
# 99  https://www.booking.com/hotel/fr/besancon.fr.h...  47.25425346,6.02163970
#
#    booking_reviews_score                                        description
# 0                    8,4  [L'ibis Besançon Centre Ville se trouve dans l...
# 1                    7,0  [Situé à quelques pas de la gare de Besançon e...
# 2                    6,8  [Situé à proximité de l'Alsace et du Jura, cet...
# 3                    8,5  [L'APPARTEMENT CENTRE HISTORIQUE est situé dan...
# 4                    8,5  [L'Hotel Vauban vous accueille à Besançon, à 2...
# ..                   ...                                                ...
# 95                   8,5  [Situé dans le centre de Besançon, l'Hôtel de ...
# 96                   7,7  [Cet hôtel Mercure est situé dans le centre-vi...
# 97                   8,2  [Le Best Western Citadelle est situé dans le c...
# 98                   8,6  [Vous pouvez bénéficier d'une réduction Genius...
# 99                   7,9  [Vous pouvez bénéficier d'une réduction Genius...
#
# [100 rows x 6 columns]

# %%
top_hotels_df.dtypes
# Out:
# city                     object
# hotel_name               object
# booking_url              object
# lat_lon coordinates      object
# booking_reviews_score    object
# description              object
# dtype: object

# %%
top_hotels_df['hotel_name'] = top_hotels_df['hotel_name'].str.strip()
top_hotels_df['latitude'] = top_hotels_df['lat_lon coordinates'].str.split(',').apply(lambda x: x[0]).astype(float)
top_hotels_df['longitude'] = top_hotels_df['lat_lon coordinates'].str.split(',').apply(lambda x: x[1]).astype(float)
top_hotels_df['booking_reviews_score'] = top_hotels_df['booking_reviews_score'].str.replace(',','.').astype(float)
top_hotels_df['description'] = top_hotels_df['description'].str.join('\n')
top_hotels_df = top_hotels_df.drop(columns = ['lat_lon coordinates'])
top_hotels_df
# Out:
#         city                               hotel_name  \
# 0   Besancon               ibis Besançon Centre Ville
# 1   Besancon                       Contact Hôtel Foch
# 2   Besancon  Premiere Classe Besancon Ecole Valentin
# 3   Besancon            APPARTEMENT CENTRE HISTORIQUE
# 4   Besancon                             Hotel Vauban
# ..       ...                                      ...
# 95  Besancon                           Hôtel de Paris
# 96  Besancon             Mercure Besancon Parc Micaud
# 97  Besancon                   Best Western Citadelle
# 98  Besancon                     Hôtel AKENA BESANCON
# 99  Besancon                     ibis Styles Besançon
#
#                                           booking_url  booking_reviews_score  \
# 0   https://www.booking.com/hotel/fr/ibis-besancon...                    8.4
# 1   https://www.booking.com/hotel/fr/foch-besancon...                    7.0
# 2   https://www.booking.com/hotel/fr/premiere-clas...                    6.8
# 3   https://www.booking.com/hotel/fr/appartement-c...                    8.5
# 4   https://www.booking.com/hotel/fr/vauban-besanc...                    8.5
# ..                                                ...                    ...
# 95  https://www.booking.com/hotel/fr/de-paris-besa...                    8.5
# 96  https://www.booking.com/hotel/fr/besancon-parc...                    7.7
# 97  https://www.booking.com/hotel/fr/bestwesternci...                    8.2
# 98  https://www.booking.com/hotel/fr/akena-besanco...                    8.6
# 99  https://www.booking.com/hotel/fr/besancon.fr.h...                    7.9
#
#                                           description   latitude  longitude
# 0   L'ibis Besançon Centre Ville se trouve dans la...  47.240456   6.025995
# 1   Situé à quelques pas de la gare de Besançon et...  47.246197   6.023351
# 2   Situé à proximité de l'Alsace et du Jura, cet ...  47.270441   5.998272
# 3   L'APPARTEMENT CENTRE HISTORIQUE est situé dans...  47.234324   6.027735
# 4   L'Hotel Vauban vous accueille à Besançon, à 2 ...  47.239863   6.021399
# ..                                                ...        ...        ...
# 95  Situé dans le centre de Besançon, l'Hôtel de P...  47.238565   6.025325
# 96  Cet hôtel Mercure est situé dans le centre-vil...  47.242288   6.031795
# 97  Le Best Western Citadelle est situé dans le ce...  47.231541   6.026580
# 98  Vous pouvez bénéficier d'une réduction Genius ...  47.235475   5.900085
# 99  Vous pouvez bénéficier d'une réduction Genius ...  47.254253   6.021640
#
# [100 rows x 7 columns]

# %%
print("------------------------------ Showing description of randomly picked hotels : --------------------------------------\n")
[print(descr, "\n----------------------------------------------------------------\n") for descr in top_hotels_df['description'].sample(10)]
print()
# Out:
# ------------------------------ Showing description of randomly picked hotels : --------------------------------------
#
# Situé dans le centre-ville de Dijon, à seulement 3 minutes à pied de la place de la République, l'Aparthotel Adagio Access Dijon République propose une réception ouverte 24h/24 et une connexion Wi-Fi gratuite dans l'ensemble de ses locaux. Le musée des Beaux-Arts est à 15 minutes à pied.
# Climatisées, tous les hébergements disposent d'une pièce à vivre avec une télévision, d'un bureau et d'une salle de bains munie d'un sèche-cheveux. Leur cuisine entièrement équipée possède un micro-ondes, des plaques de cuisson et un réfrigérateur.
# Vous pourrez préparer des repas faits maison dans le studio ou l'appartement. Un petit-déjeuner buffet est servi chaque matin dans la salle prévue à cet effet de l'établissement, tandis que les enfants de 4 à 11 ans profiteront de tarifs réduits. Vous trouverez des épiceries et des restaurants à quelques minutes à pied.
# Classé bâtiment respectueux de l'environnement en raison de son toit photovoltaïque, l'appart'hôtel est facilement accessible en transports en commun. Le tramway et le bus L3 assurent un accès direct à la gare de Dijon, qui est à 500 mètres du parc des expositions de Dijon Congrexpo. Vous pourrez utiliser le parking privé sur place, moyennant des frais supplémentaires.
# ----------------------------------------------------------------
#
# L’ibis Besançon la City se trouve sur les rives du Doubs, dans le quartier d’affaires La City, à 10 minutes de marche du centre-ville de Besançon et de ses musées. Vous rejoindrez la Citadelle en 35 minutes à pied.
# L’établissement propose des chambres climatisées, dont 4 sont accessibles aux personnes à mobilité réduite.
# Tous les matins, vous dégusterez un petit-déjeuner buffet incluant des mets sucrés et salés tels que des œufs, de la salade de fruits, des yaourts et des jus de fruits. Le restaurant Bistro Régent propose un menu de style bistro à base de produits frais.
# Une réception ouverte 24h/24 est présente sur place et un parking souterrain sécurisé est disponible moyennant des frais supplémentaires.
# ----------------------------------------------------------------
#
# L'Hotel Victor Hugo & Spa propose un hébergement à 50 mètres de la gare de Besançon-Viotte et à seulement 15 minutes à pied du centre-ville historique de Besançon. De nombreux logements donnent sur un jardin intérieur.
# Tous les hébergements sont munis d’une salle de bains privative, d’une télévision par satellite, d’un téléphone et d’une connexion Wi-Fi gratuite.
# Avant de partir à la découverte de la capitale de la Franche-Comté, vous pourrez prendre le petit-déjeuner sur place afin de bien commencer la journée.
# Équipées et modulables, les salles de réunion sur place peuvent accueillir des groupes de 45 personnes maximum.
# Sur place, toutes les personnes âgées d’au moins 12 ans pourront profiter de la salle de sport, de la piscine extérieure chauffée, du sauna, des 2 jacuzzis, du hammam, de la douche sensorielle et de la salle de détente munie d’un mur de sel. Des massages utilisant les produits de marque Cinq Mondes sont également proposés.
# Un parking privé sécurisé est mis à votre disposition sur place.
# ----------------------------------------------------------------
#
# Situé le long de la route des vins d'Alsace, l'appartement 1 chambre de la Résidence Vénus se trouve à 13 km du club de golf d'Ammerschwihr. L'établissement dispose d'une télévision, d'une radio et d'une cuisine entièrement équipée.
# Cet appartement moderne dispose d'un salon avec un canapé-lit et un lecteur CD. La cuisine est équipée d'un four, d'une cuisinière et d'un grille-pain. Gratuit Une connexion Wi-Fi est disponible et la salle de bains privative est équipée d'une douche.
# Situé dans le village historique d'Eguisheim, cet établissement se trouve à 15 minutes de route de Colmar et à 32 km du château de Koenigsbourg.
# ----------------------------------------------------------------
#
# L’Appart'City Strasbourg Centre bénéficie d’un emplacement idéal dans le centre de Strasbourg, à 10 minutes de marche de la gare. Cet établissement a obtenu le label Clef Verte et propose des studios indépendants offrant une vue sur la ville. Une connexion Internet par fibre optique est disponible.
# Décorés dans un style contemporain, les appartements disposent du chauffage, d'une télévision à écran plat et d'une salle de bains privative pourvue d’une douche. Leur kitchenette est équipée d’un lave-vaisselle, d’un réfrigérateur et d’ustensiles de cuisine.
# Un petit-déjeuner buffet peut être servi tous les matins sur demande. Le petit-déjeuner se compose de différents pains, notamment sans gluten, de viennoiseries ainsi que de boissons chaudes et froides. De la salade de fruits, des fruits frais, du fromage et des yaourts sont également proposés.
# Une bagagerie est disponible moyennant un supplément par valise.
# L’Appart'City Strasbourg se trouve à 17 km de l’aéroport de Strasbourg-Entzheim. Un parking privé est disponible sur place, sur réservation préalable et moyennant des frais supplémentaires.
# ----------------------------------------------------------------
#
# Vous pouvez bénéficier d'une réduction Genius dans l'établissement Appartements Le 32 !
#  pour économiser.
# L'établissement Le 32 propose un hébergement indépendant et idéalement situé dans le centre de Strasbourg, près de la cathédrale et de la célèbre place Gutenberg.
# Les appartements et les studios disposent tous d'une télévision à écran plat et d'un lecteur DVD. Chacun comprend un coin repas et une kitchenette entièrement équipée avec notamment un réfrigérateur, un four micro-ondes et une cafetière Nespresso.
# Ils présentent un cadre contemporain avec des murs blancs et un mobilier moderne. La plupart des chambres possèdent leur propre salle de bains privative avec douche.
# L'établissement Le 32 bénéficie d'un emplacement pratique en Alsace, à 17 km de l'aéroport de Strasbourg et à 2,5 km de la gare. Il se trouve dans la zone piétonne, à 250 mètres tout au plus du parking public le plus proche.
# ----------------------------------------------------------------
#
# Offrant une vue sur la mer, La Rade propose des hébergements dotés d’un balcon et d’une bouilloire situés à environ 250 mètres de la plage de la Grande Mer. Dans les environs, vous pourrez pratiquer des activités telles que la randonnée et la pêche. Un parking privé est accessible gratuitement sur place.
# L’appartement comprend 1 chambre, une télévision à écran plat, un lave-linge, 1 salle de bains pourvue d’une douche, ainsi qu’une cuisine équipée avec lave-vaisselle et micro-ondes.
# Cet appartement s’ouvre sur une terrasse.
# La plage du Bestouan se trouve à 350 mètres de La Rade, tandis que la plage d'Anse de Corton est à moins de 1 km. L’aéroport de Marseille-Provence, le plus proche, est implanté à 51 km.
# ----------------------------------------------------------------
#
# Cet établissement est à 6 minutes à pied de la plage. Vue sur la mer.Le Cassis est un hébergement en bord de mer situé à Cassis, à 300 mètres de Bestouan et à moins de 1 km de la plage de l'Anse de Corton. Cet hébergement climatisé se trouve à 150 mètres de la Grande Mer. Vous bénéficierez d'un parking privé sur place et d'une connexion Wi-Fi gratuite.
# Cet appartement comprend une chambre, une salle de bains, du linge de lit, des serviettes, une télévision à écran plat, un coin repas, une cuisine entièrement équipée et un balcon avec vue sur la mer.
# Vous pourrez pratiquer la randonnée et la pêche à proximité.
# Le cap Canaille se trouve à 2,6 km. L'aéroport le plus proche, celui de Marseille Provence, est situé à 36 km.Cassis.
# ----------------------------------------------------------------
#
# Situé à 100 mètres du marché de Noël d'Eguisheim, le Guesthouse Les 3 Chateaux propose une terrasse et une connexion Wi-Fi gratuite.
# Revêtus de carrelage, les logements disposent d’un coin salon avec une télévision par câble à écran plat et d’une salle de bains privative. Dotée d’un coin repas, leur cuisine entièrement équipée comporte un micro-ondes, un réfrigérateur, un four, une bouilloire et une machine à café.
# Pendant votre séjour, vous pourrez vous détendre dans le jardin et partir en randonnée dans les environs.
# L'aéroport le plus proche, celui de Bâle-Mulhouse-Fribourg, est implanté à 52 km.
# ----------------------------------------------------------------
#
# Situé à 1 km de la gare de Strasbourg ainsi qu'à 1,5 km du quartier de La Petite France, l'établissement City Résidence Strasbourg Centre dispose d'une réception ouverte 24h/24 et propose des hébergements indépendants et insonorisés. Vous bénéficierez gratuitement d'une connexion Wi-Fi dans l'ensemble des locaux.
# Les suites spacieuses comportent une télévision à écran plat, un coin repas ainsi qu'une kitchenette entièrement équipée. Elles comprennent également une salle de bains privative pourvue d'une douche.
# Le City Résidence Strasbourg Centre sert un petit-déjeuner buffet quotidien dans la salle à manger.
# Le City Résidence Strasbourg Centre est implanté à 20 minutes de marche de la cathédrale de Strasbourg et à 2 km du parc des expositions de la ville.
# ----------------------------------------------------------------

# %%
weather_df.merge(top_hotels_df).sort_values(['rank','booking_reviews_score'], ascending = [True, False])
# Out:
#     id       city  feels_like.day      pop  delta_with_ideal_temp   pop_%  \
# 14   0  Eguisheim        30.43625  0.12375                      0  12.375
# 8    0  Eguisheim        30.43625  0.12375                      0  12.375
# 2    0  Eguisheim        30.43625  0.12375                      0  12.375
# 9    0  Eguisheim        30.43625  0.12375                      0  12.375
# 5    0  Eguisheim        30.43625  0.12375                      0  12.375
# ..  ..        ...             ...      ...                    ...     ...
# 87   4     Cassis        30.25500  0.19250                      0  19.250
# 84   4     Cassis        30.25500  0.19250                      0  19.250
# 94   4     Cassis        30.25500  0.19250                      0  19.250
# 95   4     Cassis        30.25500  0.19250                      0  19.250
# 98   4     Cassis        30.25500  0.19250                      0  19.250
#
#     delta_temp_scaled  pop_scaled  score_to_minimize  rank  \
# 14          -1.288998   -0.568045          -1.857044     1
# 8           -1.288998   -0.568045          -1.857044     1
# 2           -1.288998   -0.568045          -1.857044     1
# 9           -1.288998   -0.568045          -1.857044     1
# 5           -1.288998   -0.568045          -1.857044     1
# ..                ...         ...                ...   ...
# 87          -1.288998   -0.196616          -1.485615     5
# 84          -1.288998   -0.196616          -1.485615     5
# 94          -1.288998   -0.196616          -1.485615     5
# 95          -1.288998   -0.196616          -1.485615     5
# 98          -1.288998   -0.196616          -1.485615     5
#
#                                         hotel_name  \
# 14                          La Grange de Madeleine
# 8                                   Fleur de Vigne
# 2                                 Au coup de coeur
# 9                              Elsass Design Hygge
# 5                          Les chambres du domaine
# ..                                             ...
# 87        Best Western Hotel & SPA Coeur De Cassis
# 84                 Best Western Plus Hôtel la Rade
# 94  The Originals Boutique, Hôtel Cassitel, Cassis
# 95                                  Hotel Le Golfe
# 98                                  Hotel Liautaud
#
#                                           booking_url  booking_reviews_score  \
# 14  https://www.booking.com/hotel/fr/la-grange-de-...                    9.7
# 8   https://www.booking.com/hotel/fr/fleur-de-vign...                    9.6
# 2   https://www.booking.com/hotel/fr/au-coup-de-co...                    9.5
# 9   https://www.booking.com/hotel/fr/elsass-design...                    9.4
# 5   https://www.booking.com/hotel/fr/les-chambres-...                    9.3
# ..                                                ...                    ...
# 87  https://www.booking.com/hotel/fr/du-grand-jard...                    8.1
# 84  https://www.booking.com/hotel/fr/la-rade-cassi...                    8.0
# 94  https://www.booking.com/hotel/fr/interhotel-ca...                    7.7
# 95  https://www.booking.com/hotel/fr/le-golfe-cass...                    7.7
# 98  https://www.booking.com/hotel/fr/liautaud.fr.h...                    7.5
#
#                                           description   latitude  longitude
# 14  La Grange de Madeleine est située à Eguisheim....  48.041783   7.306547
# 8   Vous pouvez bénéficier d'une réduction Genius ...  48.046113   7.305163
# 2   Situé à Eguisheim, l'établissement Au coup de ...  48.043788   7.304967
# 9   Situé à Eguisheim, l'Elsass Design Hygge propo...  48.042030   7.304598
# 5   Situé à Eguisheim, en Alsace, avec le marché d...  48.042963   7.307216
# ..                                                ...        ...        ...
# 87  Cet établissement est à 3 minutes à pied de la...  43.214573   5.540147
# 84  Cet établissement est à 4 minutes à pied de la...  43.215230   5.533697
# 94  Cet établissement est à 2 minutes à pied de la...  43.213706   5.538958
# 95  Cet établissement est à 1 minute à pied de la ...  43.214434   5.535295
# 98  Cet établissement est à 1 minute à pied de la ...  43.214030   5.538590
#
# [100 rows x 16 columns]

# %%
top_hotels_df.to_csv('hotels_data.csv')
